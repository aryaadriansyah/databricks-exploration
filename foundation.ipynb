# %% [markdown]
# # Data Ingestion towards pipelines

# %%
spark.catalog.clearCache()

# %% [markdown]
# ## Initial Spark Configuration

# %%
# %python
# client_id = <stored in KeyVault, accessible through secretScope>
# client_secret = <stored in KeyVault, accessible through secretScope>
# tenant_id = '720b637a-655a-40cf-816a-f22f40755c2c'

# %%
spark.conf.set("fs.azure.account.auth.type.stiidigiiar01dev.dfs.core.windows.net", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type.stiidigiiar01dev.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id.stiidigiiar01dev.dfs.core.windows.net", dbutils.secrets.get(scope="scope-kviidigiiardbrckdev", key="app-id"))
spark.conf.set("fs.azure.account.oauth2.client.secret.stiidigiiar01dev.dfs.core.windows.net", dbutils.secrets.get(scope="scope-kviidigiiardbrckdev", key="app-secret"))
spark.conf.set("fs.azure.account.oauth2.client.endpoint.stiidigiiar01dev.dfs.core.windows.net", "https://login.microsoftonline.com/720b637a-655a-40cf-816a-f22f40755c2c/oauth2/token")

# %% [markdown]
# ## Test connectivity to Key Values

# %%
dbutils.secrets.listScopes()

# %%
dbutils.secrets.list(scope='scope-kviidigiiardbrckdev')

# %%
dbutils.fs.ls("abfss://countries@stiidigiiar01dev.dfs.core.windows.net")
